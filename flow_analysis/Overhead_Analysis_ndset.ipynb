# %%
import plotly.graph_objects as go
import networkx as nx
import os

# reading input log file

# test_name = "ddmd"
# test_name = "vist"
# test_name = "s9f9p8"
# test_name = "f24s9p12_1"
# test_name = "ss_f24s9p12" # mapping to workload_name=pyflextrkr
# test_name = "f48s9p24_1" # mapping to workload_name=pyflextrkr
# test_name = "h5bench-sync-write-3d-contig-contig-read-full-80g_3"

# stat_path=f"example_stat/{test_name}"
# image_path=f"{stat_path}/images"

# test_name = "strong_scale"
WORKLOAD_NAME = "pyflextrkr" # choices: pyflextrkr --> f48s9p24, h5bench --> 

VFD_ACCESS_SKIP=10

ADD_ADDR=False

# %%
# My utility functions
import utils.stat_loader as sload
import utils.stat_print as sp
import utils.vfd_stat2graph as vfd2g
import utils.vfd_graph2sankey as vfd2sk
import utils.full_stat2graph as f2g

# %% [markdown]
# # Improve Functions
# ## TODO
# - Add dataset nodes
# - Add file address ordering nodes

# %%
def show_detail_overhead_old(stat_type, file_dict, task_list, workflow_time=0, workload_name="pyflextrkr"):
    overhead_dict = {
        "VOL": ["VOL-Init(us)", "VOL-Term(us)", "VOL-Log(us)",
                "VOL-HT-Add(us)", "VOL-HT-Rm(us)", "VOL-HT-Search(us)",
                "VOL-FILE_LL-Add(us)", "VOL-FILE_LL-Rm(us)", "VOL-FILE_LL-Update(us)",
                "VOL-DS_LL-Add(us)", "VOL-DS_LL-Rm(us)", "VOL-DS_LL-Update(us)",
                "VOL-GRP_LL-Add(us)", "VOL-GRP_LL-Rm(us)",
                "VOL-DT_LL-Add(us)", "VOL-DT_LL-Rm(us)"],

        "VFD": ["VFD-Init(us)", "VFD-Term(us)", "VFD-Tracker-Init(us)", "VFD-Stat-Add(us)", 
                "VFD-Stat-Update(us)", "VFD-Stat-Rm(us)", "VFD-Stat-Log(us)"]
    }
    
    
    overhead_time_list = []
    first_file_time = -1
    last_file_time = -1
    
    file_overhead_dict = {}
    
    # initialize the dict with task_list and overhead_type
    for pid_file, pid_stat in file_dict.items():
        file_overhead_dict[pid_file] = {}
        for task in task_list:
            file_overhead_dict[pid_file][task] = {}
            for overhead_type in overhead_dict[stat_type]:
                file_overhead_dict[pid_file][task][overhead_type] = []

    for pid_file, pid_stat in file_dict.items():
        prev_task = None
        task_pid = (pid_file.split("/")[-1]).split("-")[0]      
        for entry in pid_stat:
            if "Task" in entry.keys():
                task_time = entry["Task"]
                overhead_time_list.append(task_time)
                if stat_type == "VOL":
                    
                    if prev_task is not None:
                        for overhead_type in overhead_dict[stat_type]:
                            file_overhead_dict[pid_file][prev_task][overhead_type].append(task_time[overhead_type])
                
                elif stat_type == "VFD":
                    task_name = task_time['task_name']
                    # task_name = task_name.split("-")[0]
                    task_name = task_name.replace(f"-{task_pid}","")
                    for overhead_type in overhead_dict[stat_type]:
                        file_overhead_dict[pid_file][task_name][overhead_type].append(task_time[overhead_type])
                    # Get the other entry.keys() to get first and last task time, ther eis only 2 keys 
                    other_keys = [key for key in entry.keys() if key != "Task"]
                    other_key = other_keys[0]
                    first_file_time, last_file_time = get_first_last_file_time(entry[other_key], first_file_time, last_file_time)
            else:
                
                file_id = list(entry.keys())[0]
                first_file_time, last_file_time = get_first_last_file_time(entry[file_id], first_file_time, last_file_time)
                
                if "task_name" in entry[file_id].keys():
                    task_name = entry[file_id]['task_name']
                    # split task_name-pid to get task_name only
                    # task_name = task_name.split("-")[0]
                    task_name = task_name.replace(f"-{task_pid}","")
                    prev_task = task_name
    
     
    if workload_name == "pyflextrkr":
        task_overhead_dict = {}
        # initialize the dict with task_list and overhead_type
        for task in task_list:
            task_overhead_dict[task] = {}
            for overhead_type in overhead_dict[stat_type]:
                task_overhead_dict[task][overhead_type] = 0

        for pid_file, overhead_time_dict in file_overhead_dict.items():
            # print(f"{pid_file}: {overhead_time_dict}")
            for task in task_list:
                for overhead_type in overhead_time_dict[task]:
                    pid_overhead = sum(overhead_time_dict[task][overhead_type])
                    task_overhead = task_overhead_dict[task][overhead_type]
                    
                    # # pick only 
                    if pid_overhead > task_overhead:
                        task_overhead_dict[task][overhead_type] = pid_overhead

        # show task_overhead_dict
        for task in task_list:
            print(f"{task}: {task_overhead_dict[task]}")
    
        # Sum all overhead except VOL-Overhead(us)/VFD-Overhead(us)
        for task in task_list:
            task_overhead_dict[task]["Sum-Overhead(us)"] = 0
            for overhead_type in overhead_dict[stat_type]:
                # Pick the largest value of overhead_type
                # print(f'{task}: {overhead_type}: {overhead_time_dict[task][overhead_type]}')
                task_overhead_dict[task]["Sum-Overhead(us)"] += task_overhead_dict[task][overhead_type]
            print(f'{task}: Sum-Overhead(us): {task_overhead_dict[task]["Sum-Overhead(us)"]}')

        if workflow_time == 0:
            workflow_time = last_file_time - first_file_time # get a estimate of workflow time from first file to last file time
        print(f"Total task time (=workflow time) (us): {workflow_time}")
        
        # Sum all tasks overhead
        sum_tasks_overhead = 0
        for task in task_list: sum_tasks_overhead += task_overhead_dict[task]["Sum-Overhead(us)"]
            
    elif workload_name == "h5bench":
        sum_tasks_overhead = 0
        for pid_file, overhead_time_dict in file_overhead_dict.items():
            # print(f"{pid_file}: {overhead_time_dict}")
            for task in task_list:
                for overhead_type in overhead_time_dict[task]:
                    pid_overhead = sum(overhead_time_dict[task][overhead_type])
                    # task_overhead = task_overhead_dict[task][overhead_type]
                    sum_tasks_overhead += pid_overhead

    # Show overhead percentage on total task time
    print(f"Sum tasks overhead (us): {sum_tasks_overhead}")
    print(f"Workflow time (us): {workflow_time}")
    print(f"Overhead percentage on total task time: {sum_tasks_overhead/workflow_time*100}%")
    
    return file_overhead_dict, sum_tasks_overhead

# Search for log file lines to get workflow time
def get_workflow_time(stat_path:str, workload_name:str=WORKLOAD_NAME):
    # Find any file with ".log" extension
    log_file = None
    for file in os.listdir(stat_path):
        if file.endswith(".log"):
            log_file = os.path.join(stat_path, file)
            break
    print(f"log_file = {log_file}")

    WORKFLOW_TIME = 0
    # Read file and search for workflow time starting with
    if workload_name == "pyflextrkr":
        # TIME_STR_START = "Pyflextrkr TIME:"
        TIME_STR_START = "Execution time:"
        with open(log_file, "r") as f:
            for line in f:
                if TIME_STR_START in line:
                    WORKFLOW_TIME = float(line.split(" ")[2])
                    # Convert from ms to us
                    WORKFLOW_TIME = WORKFLOW_TIME * 1000
                    break
    elif workload_name == "h5bench": 
        TIME_STR_START = "Execution time"
        with open(log_file, "r") as f:
            for line in f:
                if TIME_STR_START in line:
                    runtime = float(line.split(" ")[3])
                    print(f"runtime = {runtime}")
                    # Convert from ms to us
                    WORKFLOW_TIME += runtime * 1000
    else:
        print("WORKLOAD_NAME not recognized")
        WORKFLOW_TIME = 0

    print(f"get_workflow_time() WORKFLOW_TIME = {WORKFLOW_TIME} us")
    return WORKFLOW_TIME


# WORKFLOW_TIME = get_workflow_time(stat_path)
# print(f"WORKFLOW_TIME = {WORKFLOW_TIME} us")

# %%
# function to get the workflow time, which is the sum of the write and read times in each workloads
def get_workflow_times(write_times, read_times):
    workflow_times = {}
    for ds_size in write_times.keys():
        workflow_times[f'{ds_size}'] = [w + r for w,r in zip(write_times[ds_size], read_times[ds_size])]
    return workflow_times

def get_workflow_time_from_log(log_file, workload_name="pyflextrkr"):
    workflow_time = 0
    if workload_name == "pyflextrkr":
        TIME_STR_START = "Pyflextrkr TIME:"
        with open(log_file, "r") as f:
            for line in f:
                if TIME_STR_START in line:
                    workflow_time = float(line.split(" ")[2])
                    # Convert from ms to microseconds
                    workflow_time = workflow_time * 1000
                    break
    elif workload_name == "h5bench": 
        TIME_STR_START = "Execution time"
        with open(log_file, "r") as f:
            for line in f:
                if TIME_STR_START in line:
                    runtime = float(line.split(" ")[3])
                    print(f"runtime = {runtime}")
                    # Convert from ms to microseconds
                    workflow_time += runtime * 1000
    else:
        print("WORKLOAD_NAME not recognized")

    return workflow_time

def get_avg_workflow_time(dataset_prefix_name, rcnt=0, workload_name="h5bench", proc_num=1):
    trial_nums = 3
    workflow_times = []
    processed_folder = []
    
    
    for i in list(["t1", "t2", "t3"]):
        stat_path = f"{dataset_prefix_name}_{i}"
        processed_folder.append(stat_path)
        max_workflow_time = 0
        workflow_time = get_workflow_time(stat_path, workload_name=workload_name)
        max_workflow_time += workflow_time
        print(f"{stat_path} workflow_time: {workflow_time}")
        workflow_times.append(workflow_time)
    
    # for i in list(["t1", "t2", "t3"]):
    #     stat_path = f"{dataset_prefix_name}_{i}"
    #     processed_folder.append(stat_path)
    #     max_workflow_time = 0
    #     if rcnt > 0:
    #         # file_name = f"{stat_path}/sync-write-3d-contig-contig-read-{rcnt}r-h5bench.log"
            
    #         workflow_t = get_workflow_time_from_log(file_name, workload_name=workload_name)
    #         max_workflow_time += workflow_t
    #         workflow_times.append(workflow_t)
    #     else:
    #         file_name = f"{stat_path}/sync-write-3d-contig-contig-read-2r-h5bench.log"
    #         workflow_t = get_workflow_time_from_log(file_name, workload_name=workload_name)
    #         max_workflow_time += workflow_t
    #         workflow_times.append(workflow_t)

        workflow_time = max_workflow_time
    
    avg_workflow = sum(workflow_times)/trial_nums
    # print(f"processed_folder: {processed_folder}")
    # print(f"avg_workflow: {avg_workflow}")
    return avg_workflow

def get_avg_vfd_vol_overhead(dataset_prefix_name, TASK_LISTS, workload_n="pyflextrkr"):
    trial_nums = 3
    vfd_overheads = []
    vol_overheads = []
    print(f"Running workload: {workload_n}")
    for i in list(["t1", "t2", "t3"]):
        base_stat_path = f"{dataset_prefix_name}_{i}"
        vfd_files = sload.find_files_with_pattern(base_stat_path, "vfd") 
        print(f"vfd_files: {vfd_files}")
        vfd_dict = sload.load_stat_json(vfd_files)
        print("loading vfd json done")
        vol_files = sload.find_files_with_pattern(base_stat_path, "vol") 
        print(f"vol_files: {vol_files}")
        vol_dict = sload.load_stat_json(vol_files)
        print("loading vol json done")
        print("Handle VFD and VOL overhead")
        workflow_t = get_workflow_time(base_stat_path, workload_name=workload_n)
        print(f"get_avg_vfd_vol_overhead() workflow_t: {workflow_t}")
        _, sum_vfd_overhead = show_detail_overhead_old("VFD", vfd_dict, TASK_LISTS, workflow_time=workflow_t, workload_name=workload_n) #
        _, sum_vol_overhead = show_detail_overhead_old("VOL", vol_dict, TASK_LISTS, workflow_time=workflow_t, workload_name=workload_n) #
        vfd_overheads.append(sum_vfd_overhead)
        vol_overheads.append(sum_vol_overhead)
    
    avg_vfd_overhead = sum(vfd_overheads)/trial_nums
    avg_vol_overhead = sum(vol_overheads)/trial_nums
    return avg_vfd_overhead, avg_vol_overhead

# functions to get the vfd and vol overheads (%) via increasing the scalce
def get_h5bench_strong_scale_overheads(base_path, test_name, dt_size, ds_num, read_cnts=[]):
    overheads = {}
    overheads_times = {}
    for dt in dt_size:
        for size in ds_num:
            if read_cnts:
                for rcnt in read_cnts:
                    # for trial in list(["t1", "t2", "t3"]):
                    # stat_path = f"{base_path}/{test_name}/sync-write-3d-contig-contig-read-{rcnt}r"
                    stat_path = f"{base_path}/{test_name}/{dt}_ds{size}_p1_r{rcnt}"

                    #  get the average workflow time of the dataset
                    avg_workflow_time = get_avg_workflow_time(stat_path, rcnt=rcnt, workload_name="pyflextrkr")
                    print(f"avg_workflow_time (us): {avg_workflow_time}")
                    #  get the avergae overhead time of the dataset
                    TASK_LISTS = ["h5_write", "h5_read"]
                    # TASK_LISTS = [f"sync-write-3d-contig-contig-read-{rcnt}r"]
                    avg_vfd_overhead, avg_vol_overhead = get_avg_vfd_vol_overhead(stat_path, TASK_LISTS, workload_n="pyflextrkr")

                    overheads[f'{dt}Arr-{rcnt}R'] = {'vfd_overhead(%)': (avg_vfd_overhead/avg_workflow_time*100), 'vol_overhead(%)': avg_vol_overhead/avg_workflow_time*100}
                    overheads_times[f'{dt}D-{rcnt}R'] = {'vfd_overhead(us)': avg_vfd_overhead, 'vol_overhead(us)': avg_vol_overhead, 'workflow_time(us)': avg_workflow_time}
            else:

                # for trial in list(["t1", "t2", "t3"]):
                # stat_path = f"{base_path}/{test_name}/sync-write-3d-contig-contig-read"
                stat_path = f"{base_path}/{test_name}/{dt}_ds{size}_p1_r{rcnt}"
                #  get the average workflow time of the dataset
                avg_workflow_time = get_avg_workflow_time(stat_path, workload_name="pyflextrkr")
                print(f"avg_workflow_time (us): {avg_workflow_time}")
                #  get the avergae overhead time of the dataset
                TASK_LISTS = ["h5_write", "h5_read"]
                # TASK_LISTS = [f"sync-write-3d-contig-contig-read-{rcnt}r"]
                avg_vfd_overhead, avg_vol_overhead = get_avg_vfd_vol_overhead(stat_path, TASK_LISTS, workload_n="pyflextrkr")

                overheads[f'{dt}Arr-{size}DS'] = {'vfd_overhead(%)': (avg_vfd_overhead/avg_workflow_time*100), 'vol_overhead(%)': avg_vol_overhead/avg_workflow_time*100}
                overheads_times[f'{dt}D-{size}G'] = {'vfd_overhead(us)': avg_vfd_overhead, 'vol_overhead(us)': avg_vol_overhead, 'workflow_time(us)': avg_workflow_time}

    return overheads, overheads_times

def get_first_last_file_time(entry, first_file_time, last_file_time):
    if "open_time(us)" in entry.keys():
        task_open_time = entry['open_time(us)']
        if first_file_time == -1 or task_open_time < first_file_time:
            first_file_time = task_open_time
    if "close_time(us)" in entry.keys():
        task_close_time = entry['close_time(us)']
        if last_file_time == -1 or task_close_time > last_file_time:
            last_file_time = task_close_time
    return first_file_time, last_file_time

# %%
# H5BENCH_DT_PATH=f"/Users/yejie/Projects/SCS_Lab/SC24/Candice_Paper/candice_data/h5bench"
H5BENCH_DT_PATH="/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench"
subtest_name="ssd3d64_200ds_reads_rerun2" # ssd3d64_200ds_reads ssd3d64_rerun1 ssd3d64_200ds_reads
arr_size=[64]
# ds_num=[2, 20, 200, 2000, 20000] # 20000
ds_num=[200] # 20000

read_cnts=[1, 2, 4, 8, 16, 32, 64]

# get the overheads of the strong scale
strong_overheads, strong_verheads_times = get_h5bench_strong_scale_overheads(H5BENCH_DT_PATH, subtest_name, arr_size, ds_num, read_cnts)


# ToDo: Plot the overheads of the strong scale
# H5BENCH_DT_PATH="/Users/mengtang/script/dayu-tracker/flow_analysis/example_stat/strong_scale"
# Out:
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3234000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1 workflow_time: 3234000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3212000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2 workflow_time: 3212000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3217000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3 workflow_time: 3217000.0
# avg_workflow_time (us): 3221000.0
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371367-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371410-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371367-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371410-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371410-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371367-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371410-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/371367-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3234000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3234000.0
# h5_write: {'VFD-Init(us)': 72.584, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2471.649, 'VFD-Stat-Add(us)': 77.397, 'VFD-Stat-Update(us)': 10458.478, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 18.383, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1494.203, 'VFD-Stat-Add(us)': 32.905, 'VFD-Stat-Update(us)': 11642.623, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 13080.107999999998
# h5_read: Sum-Overhead(us): 13188.114
# Total task time (=workflow time) (us): 3234000.0
# Sum tasks overhead (us): 26268.221999999998
# Workflow time (us): 3234000.0
# Overhead percentage on total task time: 0.8122517625231911%
# h5_write: {'VOL-Init(us)': 4536, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1785, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 9, 'VOL-FILE_LL-Rm(us)': 76, 'VOL-FILE_LL-Update(us)': 18, 'VOL-DS_LL-Add(us)': 686, 'VOL-DS_LL-Rm(us)': 121, 'VOL-DS_LL-Update(us)': 3362, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1579, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1803, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 141, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 112, 'VOL-FILE_LL-Update(us)': 5, 'VOL-DS_LL-Add(us)': 620, 'VOL-DS_LL-Rm(us)': 115, 'VOL-DS_LL-Update(us)': 2504, 'VOL-GRP_LL-Add(us)': 2, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10594
# h5_read: Sum-Overhead(us): 6887
# Total task time (=workflow time) (us): 3234000.0
# Sum tasks overhead (us): 17481
# Workflow time (us): 3234000.0
# Overhead percentage on total task time: 0.5405380333951763%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371476-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371519-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371476-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371519-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371476-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371519-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371476-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/371519-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3212000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3212000.0
# h5_write: {'VFD-Init(us)': 73.733, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2156.686, 'VFD-Stat-Add(us)': 75.247, 'VFD-Stat-Update(us)': 10667.146, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.994, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1777.377, 'VFD-Stat-Add(us)': 34.425, 'VFD-Stat-Update(us)': 10957.855, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12972.812000000002
# h5_read: Sum-Overhead(us): 12786.651
# Total task time (=workflow time) (us): 3212000.0
# Sum tasks overhead (us): 25759.463000000003
# Workflow time (us): 3212000.0
# Overhead percentage on total task time: 0.8019758094645082%
# h5_write: {'VOL-Init(us)': 5117, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1766, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 80, 'VOL-FILE_LL-Update(us)': 13, 'VOL-DS_LL-Add(us)': 654, 'VOL-DS_LL-Rm(us)': 123, 'VOL-DS_LL-Update(us)': 3320, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1701, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1728, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 122, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 106, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 572, 'VOL-DS_LL-Rm(us)': 86, 'VOL-DS_LL-Update(us)': 2360, 'VOL-GRP_LL-Add(us)': 3, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 11081
# h5_read: Sum-Overhead(us): 6691
# Total task time (=workflow time) (us): 3212000.0
# Sum tasks overhead (us): 17772
# Workflow time (us): 3212000.0
# Overhead percentage on total task time: 0.5533001245330013%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371585-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371628-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371585-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371628-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371585-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371628-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371585-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/371628-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r1_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3217000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3217000.0
# h5_write: {'VFD-Init(us)': 44.301, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2264.045, 'VFD-Stat-Add(us)': 76.629, 'VFD-Stat-Update(us)': 10376.832, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 17.756, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1663.077, 'VFD-Stat-Add(us)': 33.165, 'VFD-Stat-Update(us)': 11018.077, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12761.807
# h5_read: Sum-Overhead(us): 12732.074999999999
# Total task time (=workflow time) (us): 3217000.0
# Sum tasks overhead (us): 25493.881999999998
# Workflow time (us): 3217000.0
# Overhead percentage on total task time: 0.7924737954616101%
# h5_write: {'VOL-Init(us)': 4790, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1678, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 67, 'VOL-FILE_LL-Update(us)': 14, 'VOL-DS_LL-Add(us)': 655, 'VOL-DS_LL-Rm(us)': 104, 'VOL-DS_LL-Update(us)': 3185, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1752, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1707, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 135, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 124, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 609, 'VOL-DS_LL-Rm(us)': 104, 'VOL-DS_LL-Update(us)': 2392, 'VOL-GRP_LL-Add(us)': 3, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10501
# h5_read: Sum-Overhead(us): 6837
# Total task time (=workflow time) (us): 3217000.0
# Sum tasks overhead (us): 17338
# Workflow time (us): 3217000.0
# Overhead percentage on total task time: 0.538949331675474%
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3406000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1 workflow_time: 3406000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3387000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2 workflow_time: 3387000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3345000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3 workflow_time: 3345000.0
# avg_workflow_time (us): 3379333.3333333335
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371078-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371035-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371078-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371035-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371078-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371035-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371078-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/371035-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3406000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3406000.0
# h5_write: {'VFD-Init(us)': 34.783, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2075.504, 'VFD-Stat-Add(us)': 42.603, 'VFD-Stat-Update(us)': 10240.215, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 17.585, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1586.248, 'VFD-Stat-Add(us)': 34.436, 'VFD-Stat-Update(us)': 16787.458, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12393.105
# h5_read: Sum-Overhead(us): 18425.727
# Total task time (=workflow time) (us): 3406000.0
# Sum tasks overhead (us): 30818.832
# Workflow time (us): 3406000.0
# Overhead percentage on total task time: 0.9048394597768643%
# h5_write: {'VOL-Init(us)': 4944, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1688, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 61, 'VOL-FILE_LL-Update(us)': 16, 'VOL-DS_LL-Add(us)': 683, 'VOL-DS_LL-Rm(us)': 120, 'VOL-DS_LL-Update(us)': 3229, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1950, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 2513, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 360, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 233, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 1220, 'VOL-DS_LL-Rm(us)': 212, 'VOL-DS_LL-Update(us)': 2414, 'VOL-GRP_LL-Add(us)': 3, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10749
# h5_read: Sum-Overhead(us): 8916
# Total task time (=workflow time) (us): 3406000.0
# Sum tasks overhead (us): 19665
# Workflow time (us): 3406000.0
# Overhead percentage on total task time: 0.5773634762184381%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371145-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371188-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371145-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371188-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371188-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371145-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371188-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/371145-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3387000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3387000.0
# h5_write: {'VFD-Init(us)': 43.017, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1947.948, 'VFD-Stat-Add(us)': 76.213, 'VFD-Stat-Update(us)': 10627.345, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.305, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1623.48, 'VFD-Stat-Add(us)': 72.509, 'VFD-Stat-Update(us)': 16451.007, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12694.523
# h5_read: Sum-Overhead(us): 18163.301000000003
# Total task time (=workflow time) (us): 3387000.0
# Sum tasks overhead (us): 30857.824
# Workflow time (us): 3387000.0
# Overhead percentage on total task time: 0.9110665485680544%
# h5_write: {'VOL-Init(us)': 4338, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1697, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 73, 'VOL-FILE_LL-Update(us)': 16, 'VOL-DS_LL-Add(us)': 656, 'VOL-DS_LL-Rm(us)': 123, 'VOL-DS_LL-Update(us)': 3253, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1598, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 2443, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 346, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 255, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 1173, 'VOL-DS_LL-Rm(us)': 218, 'VOL-DS_LL-Update(us)': 2405, 'VOL-GRP_LL-Add(us)': 2, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10164
# h5_read: Sum-Overhead(us): 8451
# Total task time (=workflow time) (us): 3387000.0
# Sum tasks overhead (us): 18615
# Workflow time (us): 3387000.0
# Overhead percentage on total task time: 0.5496014171833481%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371254-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371297-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371254-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371297-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371297-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371254-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371297-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/371254-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r2_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3345000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3345000.0
# h5_write: {'VFD-Init(us)': 62.085, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2202.874, 'VFD-Stat-Add(us)': 79.83, 'VFD-Stat-Update(us)': 10249.761, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 39.056, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1560.139, 'VFD-Stat-Add(us)': 79.804, 'VFD-Stat-Update(us)': 16882.85, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12594.55
# h5_read: Sum-Overhead(us): 18561.849
# Total task time (=workflow time) (us): 3345000.0
# Sum tasks overhead (us): 31156.398999999998
# Workflow time (us): 3345000.0
# Overhead percentage on total task time: 0.9314319581464873%
# h5_write: {'VOL-Init(us)': 4330, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1746, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 13, 'VOL-FILE_LL-Rm(us)': 75, 'VOL-FILE_LL-Update(us)': 29, 'VOL-DS_LL-Add(us)': 690, 'VOL-DS_LL-Rm(us)': 121, 'VOL-DS_LL-Update(us)': 3316, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1627, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 2508, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 394, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 200, 'VOL-FILE_LL-Update(us)': 5, 'VOL-DS_LL-Add(us)': 1215, 'VOL-DS_LL-Rm(us)': 238, 'VOL-DS_LL-Update(us)': 2407, 'VOL-GRP_LL-Add(us)': 3, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10321
# h5_read: Sum-Overhead(us): 8603
# Total task time (=workflow time) (us): 3345000.0
# Sum tasks overhead (us): 18924
# Workflow time (us): 3345000.0
# Overhead percentage on total task time: 0.5657399103139014%
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3819000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1 workflow_time: 3819000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3643000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2 workflow_time: 3643000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3658000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3 workflow_time: 3658000.0
# avg_workflow_time (us): 3706666.6666666665
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370705-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370748-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370705-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370748-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370705-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370748-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370705-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/370748-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 3819000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3819000.0
# h5_write: {'VFD-Init(us)': 54.774, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2028.112, 'VFD-Stat-Add(us)': 77.217, 'VFD-Stat-Update(us)': 10303.823, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 17.305, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1626.033, 'VFD-Stat-Add(us)': 85.811, 'VFD-Stat-Update(us)': 27363.028, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12463.926
# h5_read: Sum-Overhead(us): 29092.177
# Total task time (=workflow time) (us): 3819000.0
# Sum tasks overhead (us): 41556.103
# Workflow time (us): 3819000.0
# Overhead percentage on total task time: 1.0881409531290913%
# h5_write: {'VOL-Init(us)': 4940, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1674, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 8, 'VOL-FILE_LL-Rm(us)': 54, 'VOL-FILE_LL-Update(us)': 16, 'VOL-DS_LL-Add(us)': 631, 'VOL-DS_LL-Rm(us)': 120, 'VOL-DS_LL-Update(us)': 3212, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 2177, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 4008, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 737, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 412, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 2275, 'VOL-DS_LL-Rm(us)': 456, 'VOL-DS_LL-Update(us)': 2420, 'VOL-GRP_LL-Add(us)': 5, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10656
# h5_read: Sum-Overhead(us): 12503
# Total task time (=workflow time) (us): 3819000.0
# Sum tasks overhead (us): 23159
# Workflow time (us): 3819000.0
# Overhead percentage on total task time: 0.6064152919612464%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370857-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370814-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370857-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370814-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370857-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370814-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370857-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/370814-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 3643000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3643000.0
# h5_write: {'VFD-Init(us)': 65.479, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2056.792, 'VFD-Stat-Add(us)': 49.885, 'VFD-Stat-Update(us)': 10599.445, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 17.379, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1622.171, 'VFD-Stat-Add(us)': 74.684, 'VFD-Stat-Update(us)': 28063.698, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12771.600999999999
# h5_read: Sum-Overhead(us): 29777.932
# Total task time (=workflow time) (us): 3643000.0
# Sum tasks overhead (us): 42549.532999999996
# Workflow time (us): 3643000.0
# Overhead percentage on total task time: 1.1679805929179248%
# h5_write: {'VOL-Init(us)': 4487, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1803, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 15, 'VOL-FILE_LL-Rm(us)': 70, 'VOL-FILE_LL-Update(us)': 29, 'VOL-DS_LL-Add(us)': 675, 'VOL-DS_LL-Rm(us)': 123, 'VOL-DS_LL-Update(us)': 3304, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1808, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 4075, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 729, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 442, 'VOL-FILE_LL-Update(us)': 5, 'VOL-DS_LL-Add(us)': 2414, 'VOL-DS_LL-Rm(us)': 459, 'VOL-DS_LL-Update(us)': 2450, 'VOL-GRP_LL-Add(us)': 4, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10507
# h5_read: Sum-Overhead(us): 12393
# Total task time (=workflow time) (us): 3643000.0
# Sum tasks overhead (us): 22900
# Workflow time (us): 3643000.0
# Overhead percentage on total task time: 0.6286027998902004%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370966-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370923-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370966-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370923-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370923-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370966-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370923-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/370966-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r4_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 3658000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 3658000.0
# h5_write: {'VFD-Init(us)': 69.294, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2260.427, 'VFD-Stat-Add(us)': 47.397, 'VFD-Stat-Update(us)': 10993.768, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.612, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1510.858, 'VFD-Stat-Add(us)': 74.925, 'VFD-Stat-Update(us)': 28186.842, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 13370.886
# h5_read: Sum-Overhead(us): 29789.237
# Total task time (=workflow time) (us): 3658000.0
# Sum tasks overhead (us): 43160.123
# Workflow time (us): 3658000.0
# Overhead percentage on total task time: 1.1798830781848004%
# h5_write: {'VOL-Init(us)': 4851, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1715, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 21, 'VOL-FILE_LL-Rm(us)': 60, 'VOL-FILE_LL-Update(us)': 14, 'VOL-DS_LL-Add(us)': 679, 'VOL-DS_LL-Rm(us)': 113, 'VOL-DS_LL-Update(us)': 3301, 'VOL-GRP_LL-Add(us)': 2, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1999, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 4135, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 749, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 475, 'VOL-FILE_LL-Update(us)': 7, 'VOL-DS_LL-Add(us)': 2363, 'VOL-DS_LL-Rm(us)': 529, 'VOL-DS_LL-Update(us)': 2445, 'VOL-GRP_LL-Add(us)': 6, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10756
# h5_read: Sum-Overhead(us): 12714
# Total task time (=workflow time) (us): 3658000.0
# Sum tasks overhead (us): 23470
# Workflow time (us): 3658000.0
# Overhead percentage on total task time: 0.6416074357572443%
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 4231000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1 workflow_time: 4231000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 4248000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2 workflow_time: 4248000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 4262000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3 workflow_time: 4262000.0
# avg_workflow_time (us): 4247000.0
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372139-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372095-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372139-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372095-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372139-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372095-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372139-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/372095-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 4231000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 4231000.0
# h5_write: {'VFD-Init(us)': 68.91, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2148.724, 'VFD-Stat-Add(us)': 61.444, 'VFD-Stat-Update(us)': 10205.83, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.353, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1766.235, 'VFD-Stat-Add(us)': 72.673, 'VFD-Stat-Update(us)': 50116.552, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12484.908
# h5_read: Sum-Overhead(us): 51971.813
# Total task time (=workflow time) (us): 4231000.0
# Sum tasks overhead (us): 64456.721000000005
# Workflow time (us): 4231000.0
# Overhead percentage on total task time: 1.5234393996691091%
# h5_write: {'VOL-Init(us)': 4513, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1737, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 14, 'VOL-FILE_LL-Rm(us)': 80, 'VOL-FILE_LL-Update(us)': 30, 'VOL-DS_LL-Add(us)': 685, 'VOL-DS_LL-Rm(us)': 114, 'VOL-DS_LL-Update(us)': 3254, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1838, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 6871, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 1604, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 829, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 4666, 'VOL-DS_LL-Rm(us)': 986, 'VOL-DS_LL-Update(us)': 2414, 'VOL-GRP_LL-Add(us)': 5, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10428
# h5_read: Sum-Overhead(us): 19224
# Total task time (=workflow time) (us): 4231000.0
# Sum tasks overhead (us): 29652
# Workflow time (us): 4231000.0
# Overhead percentage on total task time: 0.7008272276057669%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372208-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372252-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372208-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372252-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372208-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372252-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372208-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/372252-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 4248000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 4248000.0
# h5_write: {'VFD-Init(us)': 63.422, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2199.951, 'VFD-Stat-Add(us)': 81.918, 'VFD-Stat-Update(us)': 12302.373, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 15.867, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1691.039, 'VFD-Stat-Add(us)': 32.796, 'VFD-Stat-Update(us)': 50461.004, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 14647.664
# h5_read: Sum-Overhead(us): 52200.706
# Total task time (=workflow time) (us): 4248000.0
# Sum tasks overhead (us): 66848.37
# Workflow time (us): 4248000.0
# Overhead percentage on total task time: 1.573643361581921%
# h5_write: {'VOL-Init(us)': 4791, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1739, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 14, 'VOL-FILE_LL-Rm(us)': 83, 'VOL-FILE_LL-Update(us)': 32, 'VOL-DS_LL-Add(us)': 679, 'VOL-DS_LL-Rm(us)': 107, 'VOL-DS_LL-Update(us)': 3274, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1458, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 7244, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 1614, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 931, 'VOL-FILE_LL-Update(us)': 5, 'VOL-DS_LL-Add(us)': 4721, 'VOL-DS_LL-Rm(us)': 1004, 'VOL-DS_LL-Update(us)': 2408, 'VOL-GRP_LL-Add(us)': 6, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10720
# h5_read: Sum-Overhead(us): 19397
# Total task time (=workflow time) (us): 4248000.0
# Sum tasks overhead (us): 30117
# Workflow time (us): 4248000.0
# Overhead percentage on total task time: 0.7089689265536724%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372318-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372361-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372318-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372361-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372318-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372361-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372318-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/372361-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r8_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 4262000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 4262000.0
# h5_write: {'VFD-Init(us)': 69.116, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2197.465, 'VFD-Stat-Add(us)': 66.874, 'VFD-Stat-Update(us)': 10362.73, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 18.272, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1398.833, 'VFD-Stat-Add(us)': 33.514, 'VFD-Stat-Update(us)': 51110.246, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12696.185
# h5_read: Sum-Overhead(us): 52560.865
# Total task time (=workflow time) (us): 4262000.0
# Sum tasks overhead (us): 65257.049999999996
# Workflow time (us): 4262000.0
# Overhead percentage on total task time: 1.531136790239324%
# h5_write: {'VOL-Init(us)': 4643, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1750, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 9, 'VOL-FILE_LL-Rm(us)': 64, 'VOL-FILE_LL-Update(us)': 17, 'VOL-DS_LL-Add(us)': 689, 'VOL-DS_LL-Rm(us)': 120, 'VOL-DS_LL-Update(us)': 3255, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1664, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 7160, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 1708, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 910, 'VOL-FILE_LL-Update(us)': 6, 'VOL-DS_LL-Add(us)': 4666, 'VOL-DS_LL-Rm(us)': 1027, 'VOL-DS_LL-Update(us)': 2445, 'VOL-GRP_LL-Add(us)': 7, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10548
# h5_read: Sum-Overhead(us): 19599
# Total task time (=workflow time) (us): 4262000.0
# Sum tasks overhead (us): 30147
# Workflow time (us): 4262000.0
# Overhead percentage on total task time: 0.7073439699671515%
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 5495000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1 workflow_time: 5495000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 5455000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2 workflow_time: 5455000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 5439000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t3 workflow_time: 5439000.0
# avg_workflow_time (us): 5463000.0
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371804-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371760-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371804-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371760-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371804-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371760-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371804-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/371760-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 5495000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 5495000.0
# h5_write: {'VFD-Init(us)': 80.791, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2325.074, 'VFD-Stat-Add(us)': 50.334, 'VFD-Stat-Update(us)': 10543.767, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.601, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1619.408, 'VFD-Stat-Add(us)': 73.991, 'VFD-Stat-Update(us)': 94620.168, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12999.966
# h5_read: Sum-Overhead(us): 96330.168
# Total task time (=workflow time) (us): 5495000.0
# Sum tasks overhead (us): 109330.134
# Workflow time (us): 5495000.0
# Overhead percentage on total task time: 1.989629372156506%
# h5_write: {'VOL-Init(us)': 4643, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1778, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 13, 'VOL-FILE_LL-Rm(us)': 70, 'VOL-FILE_LL-Update(us)': 30, 'VOL-DS_LL-Add(us)': 703, 'VOL-DS_LL-Rm(us)': 107, 'VOL-DS_LL-Update(us)': 3323, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1753, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 13303, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 3264, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 1847, 'VOL-FILE_LL-Update(us)': 7, 'VOL-DS_LL-Add(us)': 9328, 'VOL-DS_LL-Rm(us)': 1892, 'VOL-DS_LL-Update(us)': 2402, 'VOL-GRP_LL-Add(us)': 12, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10668
# h5_read: Sum-Overhead(us): 33813
# Total task time (=workflow time) (us): 5495000.0
# Sum tasks overhead (us): 44481
# Workflow time (us): 5495000.0
# Overhead percentage on total task time: 0.8094813466787989%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371872-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371915-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371872-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371915-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371872-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371915-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371872-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/371915-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r16_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 5455000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 5455000.0
# h5_write: {'VFD-Init(us)': 48.203, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2268.291, 'VFD-Stat-Add(us)': 39.727, 'VFD-Stat-Update(us)': 10272.584, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.901, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1557.066, 'VFD-Stat-Add(us)': 73.309, 'VFD-Stat-Update(us)': 92957.628, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12628.805
# h5_read: Sum-Overhead(us): 94604.904
# Total task time (=workflow time) (us): 5455000.0
# Sum tasks overhead (us): 107233.709
# Workflow time (us): 5455000.0
# Overhead percentage on total task time: 1.96578751604033%
# h5_write: {'VOL-Init(us)': 4557, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1706, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 8, 'VOL-FILE_LL-Rm(us)': 58, 'VOL-FILE_LL-Update(us)': 27, 'VOL-DS_LL-Add(us)': 674, 'VOL-DS_LL-Rm(us)': 124, 'VOL-DS_LL-Update(us)': 3248, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 2169, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 12853, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 3349, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 1694, 'VOL-FILE_LL-Update(us)': 8, 'VOL-DS_LL-Add(us)': 9118, 'VOL-DS_LL-Rm(us)': 1856, 'VOL-DS_LL-Update(us)': 2421, 'VOL-GRP_LL-Add(us)': 7, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10403
# h5_read: Sum-Overhead(us): 33482
# ...
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t2/369863-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t2/369818-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t2/369863-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t2/369818-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 7824000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 7824000.0
# h5_write: {'VFD-Init(us)': 46.53, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2308.232, 'VFD-Stat-Add(us)': 76.547, 'VFD-Stat-Update(us)': 10465.471, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 19.039, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1329.968, 'VFD-Stat-Add(us)': 39.973, 'VFD-Stat-Update(us)': 183618.158, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12896.779999999999
# h5_read: Sum-Overhead(us): 185007.138
# Total task time (=workflow time) (us): 7824000.0
# Sum tasks overhead (us): 197903.918
# Workflow time (us): 7824000.0
# Overhead percentage on total task time: 2.5294468047034764%
# h5_write: {'VOL-Init(us)': 4653, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1739, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 14, 'VOL-FILE_LL-Rm(us)': 74, 'VOL-FILE_LL-Update(us)': 30, 'VOL-DS_LL-Add(us)': 668, 'VOL-DS_LL-Rm(us)': 115, 'VOL-DS_LL-Update(us)': 3170, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 2105, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 24080, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 6708, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 3799, 'VOL-FILE_LL-Update(us)': 8, 'VOL-DS_LL-Add(us)': 18522, 'VOL-DS_LL-Rm(us)': 3867, 'VOL-DS_LL-Update(us)': 2383, 'VOL-GRP_LL-Add(us)': 24, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10464
# h5_read: Sum-Overhead(us): 61502
# Total task time (=workflow time) (us): 7824000.0
# Sum tasks overhead (us): 71966
# Workflow time (us): 7824000.0
# Overhead percentage on total task time: 0.9198108384458078%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369930-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369973-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369930-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369973-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369930-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369973-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369930-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/369973-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r32_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 7709000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 7709000.0
# h5_write: {'VFD-Init(us)': 51.387, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2167.29, 'VFD-Stat-Add(us)': 42.205, 'VFD-Stat-Update(us)': 10228.553, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.478, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1822.887, 'VFD-Stat-Add(us)': 34.905, 'VFD-Stat-Update(us)': 189065.531, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12489.435
# h5_read: Sum-Overhead(us): 190939.80099999998
# Total task time (=workflow time) (us): 7709000.0
# Sum tasks overhead (us): 203429.23599999998
# Workflow time (us): 7709000.0
# Overhead percentage on total task time: 2.638853755350888%
# h5_write: {'VOL-Init(us)': 4771, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1720, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 8, 'VOL-FILE_LL-Rm(us)': 80, 'VOL-FILE_LL-Update(us)': 16, 'VOL-DS_LL-Add(us)': 658, 'VOL-DS_LL-Rm(us)': 119, 'VOL-DS_LL-Update(us)': 3188, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1619, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 26509, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 6335, 'VOL-FILE_LL-Add(us)': 5, 'VOL-FILE_LL-Rm(us)': 4880, 'VOL-FILE_LL-Update(us)': 8, 'VOL-DS_LL-Add(us)': 18853, 'VOL-DS_LL-Rm(us)': 3905, 'VOL-DS_LL-Update(us)': 2413, 'VOL-GRP_LL-Add(us)': 18, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10561
# h5_read: Sum-Overhead(us): 64545
# Total task time (=workflow time) (us): 7709000.0
# Sum tasks overhead (us): 75106
# Workflow time (us): 7709000.0
# Overhead percentage on total task time: 0.9742638474510312%
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 12670000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1 workflow_time: 12670000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 12732000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2 workflow_time: 12732000.0
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 12611000.0 us
# /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3 workflow_time: 12611000.0
# avg_workflow_time (us): 12671000.0
# Running workload: pyflextrkr
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372497-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372454-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372497-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372454-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372454-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372497-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372454-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/372497-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t1/64_ds200_p1_t1.log
# get_workflow_time() WORKFLOW_TIME = 12670000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 12670000.0
# h5_write: {'VFD-Init(us)': 69.363, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2028.569, 'VFD-Stat-Add(us)': 76.694, 'VFD-Stat-Update(us)': 10545.868, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 56.851, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1735.16, 'VFD-Stat-Add(us)': 79.118, 'VFD-Stat-Update(us)': 361496.399, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12720.494
# h5_read: Sum-Overhead(us): 363367.528
# Total task time (=workflow time) (us): 12670000.0
# Sum tasks overhead (us): 376088.022
# Workflow time (us): 12670000.0
# Overhead percentage on total task time: 2.968334822415154%
# h5_write: {'VOL-Init(us)': 4546, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1731, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 84, 'VOL-FILE_LL-Update(us)': 14, 'VOL-DS_LL-Add(us)': 667, 'VOL-DS_LL-Rm(us)': 112, 'VOL-DS_LL-Update(us)': 3335, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1698, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 47828, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 13175, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 7247, 'VOL-FILE_LL-Update(us)': 8, 'VOL-DS_LL-Add(us)': 36385, 'VOL-DS_LL-Rm(us)': 7416, 'VOL-DS_LL-Update(us)': 2397, 'VOL-GRP_LL-Add(us)': 41, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10496
# h5_read: Sum-Overhead(us): 116201
# Total task time (=workflow time) (us): 12670000.0
# Sum tasks overhead (us): 126697
# Workflow time (us): 12670000.0
# Overhead percentage on total task time: 0.9999763220205208%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372567-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372610-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372567-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372610-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372610-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372567-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372610-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/372567-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t2/64_ds200_p1_t2.log
# get_workflow_time() WORKFLOW_TIME = 12732000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 12732000.0
# h5_write: {'VFD-Init(us)': 75.761, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2343.713, 'VFD-Stat-Add(us)': 81.518, 'VFD-Stat-Update(us)': 10527.212, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 17.288, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1679.912, 'VFD-Stat-Add(us)': 35.962, 'VFD-Stat-Update(us)': 360545.806, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 13028.204
# h5_read: Sum-Overhead(us): 362278.968
# Total task time (=workflow time) (us): 12732000.0
# Sum tasks overhead (us): 375307.172
# Workflow time (us): 12732000.0
# Overhead percentage on total task time: 2.947747188187245%
# h5_write: {'VOL-Init(us)': 4690, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1734, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 10, 'VOL-FILE_LL-Rm(us)': 83, 'VOL-FILE_LL-Update(us)': 18, 'VOL-DS_LL-Add(us)': 679, 'VOL-DS_LL-Rm(us)': 121, 'VOL-DS_LL-Update(us)': 3242, 'VOL-GRP_LL-Add(us)': 2, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 1889, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 48635, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 13075, 'VOL-FILE_LL-Add(us)': 7, 'VOL-FILE_LL-Rm(us)': 7828, 'VOL-FILE_LL-Update(us)': 8, 'VOL-DS_LL-Add(us)': 37516, 'VOL-DS_LL-Rm(us)': 7207, 'VOL-DS_LL-Update(us)': 2435, 'VOL-GRP_LL-Add(us)': 38, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10579
# h5_read: Sum-Overhead(us): 118638
# Total task time (=workflow time) (us): 12732000.0
# Sum tasks overhead (us): 129217
# Workflow time (us): 12732000.0
# Overhead percentage on total task time: 1.0148994659126611%
# vfd_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372680-vfd_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372724-vfd_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372680-vfd_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372724-vfd_data_stat.json
# loading vfd json done
# vol_files: ['/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372680-vol_data_stat.json', '/Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372724-vol_data_stat.json']
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372680-vol_data_stat.json
# loading /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/372724-vol_data_stat.json
# loading vol json done
# Handle VFD and VOL overhead
# log_file = /Users/mengtang/script/dayu-tracker/flow_analysis/h5bench/ssd3d64_200ds_reads_rerun2/64_ds200_p1_r64_t3/64_ds200_p1_t3.log
# get_workflow_time() WORKFLOW_TIME = 12611000.0 us
# get_avg_vfd_vol_overhead() workflow_t: 12611000.0
# h5_write: {'VFD-Init(us)': 46.567, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 2272.556, 'VFD-Stat-Add(us)': 79.849, 'VFD-Stat-Update(us)': 10455.96, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_read: {'VFD-Init(us)': 16.73, 'VFD-Term(us)': 0, 'VFD-Tracker-Init(us)': 1673.759, 'VFD-Stat-Add(us)': 72.938, 'VFD-Stat-Update(us)': 364248.666, 'VFD-Stat-Rm(us)': 0, 'VFD-Stat-Log(us)': 0}
# h5_write: Sum-Overhead(us): 12854.931999999999
# h5_read: Sum-Overhead(us): 366012.09300000005
# Total task time (=workflow time) (us): 12611000.0
# Sum tasks overhead (us): 378867.025
# Workflow time (us): 12611000.0
# Overhead percentage on total task time: 3.0042583855364366%
# h5_write: {'VOL-Init(us)': 4613, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 1755, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 0, 'VOL-FILE_LL-Add(us)': 9, 'VOL-FILE_LL-Rm(us)': 76, 'VOL-FILE_LL-Update(us)': 18, 'VOL-DS_LL-Add(us)': 675, 'VOL-DS_LL-Rm(us)': 109, 'VOL-DS_LL-Update(us)': 3333, 'VOL-GRP_LL-Add(us)': 1, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_read: {'VOL-Init(us)': 2206, 'VOL-Term(us)': 0, 'VOL-Log(us)': 0, 'VOL-HT-Add(us)': 47879, 'VOL-HT-Rm(us)': 0, 'VOL-HT-Search(us)': 12817, 'VOL-FILE_LL-Add(us)': 6, 'VOL-FILE_LL-Rm(us)': 6841, 'VOL-FILE_LL-Update(us)': 9, 'VOL-DS_LL-Add(us)': 35699, 'VOL-DS_LL-Rm(us)': 7528, 'VOL-DS_LL-Update(us)': 2402, 'VOL-GRP_LL-Add(us)': 38, 'VOL-GRP_LL-Rm(us)': 0, 'VOL-DT_LL-Add(us)': 0, 'VOL-DT_LL-Rm(us)': 0}
# h5_write: Sum-Overhead(us): 10589
# h5_read: Sum-Overhead(us): 115425
# Total task time (=workflow time) (us): 12611000.0
# Sum tasks overhead (us): 126014
# Workflow time (us): 12611000.0
# Overhead percentage on total task time: 0.9992387598128618%

# %%
print("*************************************************************************************************************")
print("Strong Scale Overheads")
# print(strong_overheads)
for k,v in strong_overheads.items():
    print(f"{k}: {v}")

print()

print("Strong Scale Overheads Times")
# print(strong_verheads_times)
for k,v in strong_verheads_times.items():
    print(f"{k}: {v}")
# Out:
# *************************************************************************************************************
# Strong Scale Overheads
# 64Arr-1R: {'vfd_overhead(%)': 0.8022515471385697, 'vol_overhead(%)': 0.5442512677222394}
# 64Arr-2R: {'vfd_overhead(%)': 0.9156939731702505, 'vol_overhead(%)': 0.5642533043992898}
# 64Arr-4R: {'vfd_overhead(%)': 1.1444762499999999, 'vol_overhead(%)': 0.6252607913669064}
# 64Arr-8R: {'vfd_overhead(%)': 1.5427528529942705, 'vol_overhead(%)': 0.7057216858959265}
# 64Arr-16R: {'vfd_overhead(%)': 1.9858323692720725, 'vol_overhead(%)': 0.8052840319726645}
# 64Arr-32R: {'vfd_overhead(%)': 2.5576546911048443, 'vol_overhead(%)': 0.9375459283944287}
# 64Arr-64R: {'vfd_overhead(%)': 2.9733570594270384, 'vol_overhead(%)': 1.0047299608028832}
#
# Strong Scale Overheads Times
# 64D-1R: {'vfd_overhead(us)': 25840.52233333333, 'vol_overhead(us)': 17530.333333333332, 'workflow_time(us)': 3221000.0}
# 64D-2R: {'vfd_overhead(us)': 30944.351666666666, 'vol_overhead(us)': 19068.0, 'workflow_time(us)': 3379333.3333333335}
# 64D-4R: {'vfd_overhead(us)': 42421.91966666666, 'vol_overhead(us)': 23176.333333333332, 'workflow_time(us)': 3706666.6666666665}
# 64D-8R: {'vfd_overhead(us)': 65520.71366666667, 'vol_overhead(us)': 29972.0, 'workflow_time(us)': 4247000.0}
# 64D-16R: {'vfd_overhead(us)': 108486.02233333333, 'vol_overhead(us)': 43992.666666666664, 'workflow_time(us)': 5463000.0}
# 64D-32R: {'vfd_overhead(us)': 199548.21899999995, 'vol_overhead(us)': 73147.33333333333, 'workflow_time(us)': 7802000.0}
# 64D-64R: {'vfd_overhead(us)': 376754.07300000003, 'vol_overhead(us)': 127309.33333333333, 'workflow_time(us)': 12671000.0}
